# %%
# %load_ext autoreload
# %autoreload 2

from drug_repo_metric_learning.siamese_datasets import SiameseNetworkDataset
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Import Data, for Reference

# %%
import pandas as pd

# %%
limma_metadata_6hr_10um = pd.read_csv("/home/sgf2/DBMI_server/repo/ccdata/l1000_limma_cellLine/l1000_metadata_6hr_10um.csv")
limma_es_6hr_10um = pd.read_csv("/home/sgf2/DBMI_server/repo/ccdata/l1000_limma_cellLine/l1000_es_6hr_10um.csv")
limma_match_ctrls_6hr_10um = pd.read_pickle('/home/sgf2/DBMI_server/repo/ccdata/lincs_l3_ctrls/limma_match_ctrls_6hr_10um.pkl')
limma_match_postpers_6hr_10um = pd.read_pickle('/home/sgf2/DBMI_server/repo/ccdata/lincs_l3_ctrls/limma_match_postpers_6hr_10um.pkl')

# %%
limma_metadata_6hr_10um.head()
# Out:
#                                         l1000es_name        pert_id  \
# 0                            10-DEBC_FIBRNPC_10um_6h  BRD-K70792160
# 1                                10-DEBC_NEU_10um_6h  BRD-K70792160
# 2  10H-phenothiazin-10-yl)(p-tolyl)methanone_A375...  BRD-K94919853
# 3  10H-phenothiazin-10-yl)(p-tolyl)methanone_A549...  BRD-K94919853
# 4  10H-phenothiazin-10-yl)(p-tolyl)methanone_HA1E...  BRD-K94919853
#
#                                   pert_iname            pert_desc  cell_id  \
# 0                                    10-DEBC  Akt Inhibitor X.HCl  FIBRNPC
# 1                                    10-DEBC  Akt Inhibitor X.HCl      NEU
# 2  10H-phenothiazin-10-yl)(p-tolyl)methanone                 -666     A375
# 3  10H-phenothiazin-10-yl)(p-tolyl)methanone                 -666     A549
# 4  10H-phenothiazin-10-yl)(p-tolyl)methanone                 -666     HA1E
#
#    pert_time pert_time_unit  pert_dose pert_dose_unit
# ...

# %%
limma_match_ctrls_6hr_10um.head()
# Out:
# pr_gene_id                                    16         23        25      \
# pr_gene_symbol                                  AARS      ABCF1      ABL1
# pert_id       cell_id pert_dose pert_time
# BRD-K70792160 FIBRNPC 10        6          10.590253  11.568742  8.784332
#               NEU     10        6           9.233975  13.764045  9.568012
#               NEU.KCL 10        6                NaN        NaN       NaN
# BRD-K94919853 A375    10        6           9.505615   9.465717  8.449003
#               A549    10        6           9.911240   9.064086  8.761660
#
# pr_gene_id                                   30         39         47      \
# pr_gene_symbol                                ACAA1      ACAT2       ACLY
# pert_id       cell_id pert_dose pert_time
# BRD-K70792160 FIBRNPC 10        6          9.113083   8.737153   9.433749
#               NEU     10        6          8.164038  11.754004   7.185849
# ...

# %%
limma_match_postpers_6hr_10um.head()
# Out:
# pr_gene_id                                    16         23        25      \
# pr_gene_symbol                                  AARS      ABCF1      ABL1
# pert_id       cell_id pert_dose pert_time
# BRD-K70792160 FIBRNPC 10        6          10.616397  11.458937  8.673240
#               NEU     10        6           9.446570  13.643766  9.564709
#               NEU.KCL 10        6                NaN        NaN       NaN
# BRD-K94919853 A375    10        6           9.101439   9.653332  8.170969
#               A549    10        6           9.916452   8.945151  8.631259
#
# pr_gene_id                                   30         39         47      \
# pr_gene_symbol                                ACAA1      ACAT2       ACLY
# pert_id       cell_id pert_dose pert_time
# BRD-K70792160 FIBRNPC 10        6          9.099570   9.259568   9.342113
#               NEU     10        6          8.231722  11.681145   7.402205
# ...

# %%
limma_es_6hr_10um.head()
# Out:
#                                         l1000es_name     PSME1     CISD1  \
# 0                            10-DEBC_FIBRNPC_10um_6h -0.017599 -0.406620
# 1                                10-DEBC_NEU_10um_6h -1.043900 -0.661320
# 2  10H-phenothiazin-10-yl)(p-tolyl)methanone_A375... -0.132580  2.025700
# 3  10H-phenothiazin-10-yl)(p-tolyl)methanone_A549... -0.128010 -0.039157
# 4  10H-phenothiazin-10-yl)(p-tolyl)methanone_HA1E...  1.019900  1.533800
#
#      SPDEF     ATF1      RHEB    IGF1R    FOXO3    GSTM2     RHOA  ...  \
# 0 -0.23310  0.31128  0.331740 -0.50243  0.16884  0.47993 -0.02297  ...
# 1 -0.65190 -0.66403  1.110800  0.78640 -0.32680 -0.19880 -0.10617  ...
# 2  0.11341 -0.61188  0.808060  2.10050 -0.98240  0.87325  2.17160  ...
# 3 -0.13199 -0.65234  0.771110 -0.21014  0.94189 -0.12408 -0.23673  ...
# 4 -0.11191 -3.74210  0.075082  1.49920 -2.55360  0.51987  1.79200  ...
#
#      HEBP1    FGFR4    CDKN2A   ATP11B    CD320   CDKN1B    MLLT11    CEBPZ  \
# ...

# %%
limma_match_ctrls_6hr_10um.index.get_level_values('cell_id').value_counts()
# Out:
# MCF7       5082
# PC3        5055
# A375       4749
# A549       4733
# HT29       4729
# VCAP       4719
# HCC515     4573
# HA1E       4377
# HEPG2      3483
# NEU         597
# FIBRNPC     595
# NPC         577
# Name: cell_id, dtype: int64

# %%
gene_signatures
# Out:
# pr_gene_id                                    16         23         25      \
# pr_gene_symbol                                  AARS      ABCF1       ABL1
# pert_id       cell_id pert_dose pert_time
# BRD-K70792160 FIBRNPC 10        6          10.616397  11.458937   8.673240
#               NEU     10        6           9.446570  13.643766   9.564709
# BRD-K94919853 A375    10        6           9.101439   9.653332   8.170969
#               A549    10        6           9.916452   8.945151   8.631259
#               HA1E    10        6           9.238606   9.624399   9.934814
#               HCC515  10        6          10.856926  11.638925   8.701688
#               HT29    10        6           9.062656   9.992514   7.385666
#               MCF7    10        6          10.830708  10.423295   8.108719
#               PC3     10        6           8.711792   9.859629   7.481541
#               VCAP    10        6           9.559478  11.530253   9.115809
# ...

# %% [markdown]
# ## Create pickel file

# %%
limma_metadata_6hr_10um = pd.read_csv("/home/sgf2/DBMI_server/repo/ccdata/l1000_limma_cellLine/l1000_metadata_6hr_10um.csv")
limma_es_6hr_10um = pd.read_csv("/home/sgf2/DBMI_server/repo/ccdata/l1000_limma_cellLine/l1000_es_6hr_10um.csv")
limma_match_ctrls_6hr_10um = pd.read_pickle('/home/sgf2/DBMI_server/repo/ccdata/lincs_l3_ctrls/limma_match_ctrls_6hr_10um.pkl')
limma_match_postpers_6hr_10um = pd.read_pickle('/home/sgf2/DBMI_server/repo/ccdata/lincs_l3_ctrls/limma_match_postpers_6hr_10um.pkl')

limma_metadata_24hr_10um = pd.read_csv("/home/sgf2/DBMI_server/repo/ccdata/l1000_limma_cellLine/l1000_metadata_24hr_10um.csv")
limma_es_24hr_10um = pd.read_csv("/home/sgf2/DBMI_server/repo/ccdata/l1000_limma_cellLine/l1000_es_24hr_10um.csv")
limma_match_ctrls_24hr_10um = pd.read_pickle('/home/sgf2/DBMI_server/repo/ccdata/lincs_l3_ctrls/limma_match_ctrls_24hr_10um.pkl')
limma_match_postpers_24hr_10um = pd.read_pickle('/home/sgf2/DBMI_server/repo/ccdata/lincs_l3_ctrls/limma_match_postpers_24hr_10um.pkl')

limma_metadata_24hr_5um = pd.read_csv("/home/sgf2/DBMI_server/repo/ccdata/l1000_limma_cellLine/l1000_metadata_24hr_5um.csv")
limma_es_24hr_5um = pd.read_csv("/home/sgf2/DBMI_server/repo/ccdata/l1000_limma_cellLine/l1000_es_24hr_5um.csv")
limma_match_ctrls_24hr_5um = pd.read_pickle('/home/sgf2/DBMI_server/repo/ccdata/lincs_l3_ctrls/limma_match_ctrls_24hr_5um.pkl')
limma_match_postpers_24hr_5um = pd.read_pickle('/home/sgf2/DBMI_server/repo/ccdata/lincs_l3_ctrls/limma_match_postpers_24hr_5um.pkl')

# %%
limma_match_postpers_6hr_10um = pd.read_pickle('/home/sgf2/DBMI_server/repo/ccdata/lincs_l3_ctrls/limma_match_postpers_6hr_10um.pkl')
limma_match_postpers_24hr_10um = pd.read_pickle('/home/sgf2/DBMI_server/repo/ccdata/lincs_l3_ctrls/limma_match_postpers_24hr_10um.pkl')
limma_match_postpers_24hr_5um = pd.read_pickle('/home/sgf2/DBMI_server/repo/ccdata/lincs_l3_ctrls/limma_match_postpers_24hr_5um.pkl')

# %%
(
all(limma_metadata_6hr_10um.iloc[:,0] == limma_es_6hr_10um.iloc[:,0]),
all(limma_metadata_24hr_10um.iloc[:,0] == limma_es_24hr_10um.iloc[:,0]),
all(limma_metadata_24hr_5um.iloc[:,0] == limma_es_24hr_5um.iloc[:,0])
)
# Out:
# (True, True, True)

# %%
l1000_gene_names = limma_match_postpers_6hr_10um \
    .columns \
    .get_level_values('pr_gene_symbol') \
    .to_list()
    
limma_sigs_6hr_10um = pd.merge(limma_metadata_6hr_10um, limma_es_6hr_10um) \
                        .set_index(limma_metadata_6hr_10um.columns.to_list()) \
                        .rename(columns = {'TOMM70':'TOMM70A'}) \
                        [l1000_gene_names] 
            
limma_sigs_6hr_10um.columns = limma_match_postpers_6hr_10um.columns


limma_sigs_24hr_10um = pd.merge(limma_metadata_24hr_10um, limma_es_24hr_10um) \
                        .set_index(limma_metadata_24hr_10um.columns.to_list()) \
                        .rename(columns = {'TOMM70':'TOMM70A'}) \
                        [l1000_gene_names] 
            
limma_sigs_24hr_10um.columns = limma_match_postpers_24hr_10um.columns


limma_sigs_24hr_5um = pd.merge(limma_metadata_24hr_5um, limma_es_24hr_5um) \
                        .set_index(limma_metadata_24hr_5um.columns.to_list()) \
                        .rename(columns = {'TOMM70':'TOMM70A'}) \
                        [l1000_gene_names] 
            
limma_sigs_24hr_5um.columns = limma_match_postpers_24hr_5um.columns

(limma_sigs_24hr_5um.shape, limma_sigs_24hr_10um.shape, limma_sigs_6hr_10um.shape)
# Out:
# ((32160, 978), (37289, 978), (43268, 978))

# %%
limma_match_ctrls_6hr_10um = limma_match_ctrls_6hr_10um.loc[
    limma_match_ctrls_6hr_10um \
    .index.get_level_values('cell_id') != "NEU.KCL"
]

limma_match_ctrls_24hr_10um = limma_match_ctrls_24hr_10um.loc[
    limma_match_ctrls_24hr_10um \
    .index.get_level_values('cell_id') != "NEU.KCL"
]

limma_match_ctrls_24hr_5um = limma_match_ctrls_24hr_5um.loc[
    limma_match_ctrls_24hr_5um \
    .index.get_level_values('cell_id') != "NEU.KCL"
]

# %%
import numpy as np
np.where( limma_sigs_6hr_10um.index.get_level_values('pert_id').to_list() != \
limma_match_postpers_6hr_10um.index.get_level_values('pert_id').to_list()
        )
# Out:
# (array([0]),)

# %%
limma_sigs_6hr_10um.shape
# Out:
# (43268, 978)

# %%
limma_match_ctrls_6hr_10um.shape
# Out:
# (43269, 978)

# %%
limma_sigs_6hr_10um.tail()
# Out:
# pr_gene_id                                                                                                                                         16      \
# pr_gene_symbol                                                                                                                                       AARS
# l1000es_name                 pert_id       pert_iname     pert_desc                    cell_id pert_time pert_time_unit pert_dose pert_dose_unit
# zuclopenthixol_HEPG2_10um_6h BRD-K28761384 zuclopenthixol -666                         HEPG2   6         h              10        um              0.77781
# zuclopenthixol_HT29_10um_6h  BRD-K28761384 zuclopenthixol -666                         HT29    6         h              10        um             -0.48257
# zuclopenthixol_MCF7_10um_6h  BRD-K28761384 zuclopenthixol -666                         MCF7    6         h              10        um              0.37806
# ...

# %%
limma_match_ctrls_6hr_10um.tail()
# Out:
# pr_gene_id                                    16         23        25      \
# pr_gene_symbol                                  AARS      ABCF1      ABL1
# pert_id       cell_id pert_dose pert_time
# BRD-K28761384 HEPG2   10        6           9.913753  11.522416  6.805526
#               HT29    10        6           8.801733  10.258688  6.737159
#               MCF7    10        6          11.152717  10.044906  6.831652
#               PC3     10        6           9.027858   9.975899  8.105411
#               VCAP    10        6           9.351610  11.642001  9.841403
#
# pr_gene_id                                   30         39        47      \
# pr_gene_symbol                                ACAA1      ACAT2      ACLY
# pert_id       cell_id pert_dose pert_time
# BRD-K28761384 HEPG2   10        6          8.636164  10.628932  9.838034
#               HT29    10        6          7.563932   9.755575  8.340927
# ...

# %% [raw]
# # 6hr 10um
# matched_rows_list = []
# for row in limma_sigs_6hr_10um.index.to_native_types():
#     pid, cid, tim, dos = row[1], row[4], row[5], row[7]
#     matched_rows_list.append(limma_match_ctrls_6hr_10um.query('pert_id == @pid & ' + \
#                                  'cell_id == @cid & ' + \
#                                  'pert_dose == @dos & ' + \
#                                  'pert_time == @tim')
#     )
# limma_match_ctrls_6hr_10um_realmatch = pd.concat(matched_rows_list)
# print(limma_match_ctrls_6hr_10um_realmatch.shape)
#
# # 24hr 10um
# matched_rows_list = []
# for row in limma_sigs_24hr_10um.index.to_native_types():
#     pid, cid, tim, dos = row[1], row[4], row[5], row[7]
#     matched_rows_list.append(limma_match_ctrls_24hr_10um.query('pert_id == @pid & ' + \
#                                  'cell_id == @cid & ' + \
#                                  'pert_dose == @dos & ' + \
#                                  'pert_time == @tim')
#     )
# limma_match_ctrls_24hr_10um_realmatch = pd.concat(matched_rows_list)
# print(limma_match_ctrls_24hr_10um_realmatch.shape)
#
#
# # 24hr 5um
# matched_rows_list = []
# for row in limma_sigs_24hr_5um.index.to_native_types():
#     pid, cid, tim, dos = row[1], row[4], row[5], row[7]
#     matched_rows_list.append(limma_match_ctrls_24hr_5um.query('pert_id == @pid & ' + \
#                                  'cell_id == @cid & ' + \
#                                  'pert_dose == @dos & ' + \
#                                  'pert_time == @tim')
#     )
# limma_match_ctrls_24hr_5um_realmatch = pd.concat(matched_rows_list)
# print(limma_match_ctrls_24hr_5um_realmatch.shape)

# %%
# 6hr 10um
matched_rows_list = []
for row in tqdm(limma_sigs_6hr_10um.index.to_native_types()):
    pid, cid, tim, dos = row[1], row[4], row[5], row[7]
    matched_rows_list.append(limma_match_postpers_6hr_10um.query('pert_id == @pid & ' + \
                                 'cell_id == @cid & ' + \
                                 'pert_dose == @dos & ' + \
                                 'pert_time == @tim')
    )
limma_match_postpers_6hr_10um_realmatch = pd.concat(matched_rows_list)
print(limma_match_postpers_6hr_10um_realmatch.shape)


# 24hr 10um
matched_rows_list = []
for row in tqdm(limma_sigs_24hr_10um.index.to_native_types()):
    pid, cid, tim, dos = row[1], row[4], row[5], row[7]
    matched_rows_list.append(limma_match_postpers_24hr_10um.query('pert_id == @pid & ' + \
                                 'cell_id == @cid & ' + \
                                 'pert_dose == @dos & ' + \
                                 'pert_time == @tim')
    )
limma_match_postpers_24hr_10um_realmatch = pd.concat(matched_rows_list)
print(limma_match_postpers_24hr_10um_realmatch.shape)


# 24hr 5um
matched_rows_list = []
for row in tqdm(limma_sigs_24hr_5um.index.to_native_types()):
    pid, cid, tim, dos = row[1], row[4], row[5], row[7]
    matched_rows_list.append(limma_match_postpers_24hr_5um.query('pert_id == @pid & ' + \
                                 'cell_id == @cid & ' + \
                                 'pert_dose == @dos & ' + \
                                 'pert_time == @tim')
    )
limma_match_postpers_24hr_5um_realmatch = pd.concat(matched_rows_list)
print(limma_match_postpers_24hr_5um_realmatch.shape)
# Out:
# (43268, 978)
# (43268, 978)
# (37289, 978)
# (37289, 978)
# (32160, 978)
# (32160, 978)

# %%
all([
    all(limma_sigs_6hr_10um.index.get_level_values('pert_id') == 
        limma_match_ctrls_6hr_10um_realmatch.index.get_level_values('pert_id')),
    all(limma_sigs_6hr_10um.index.get_level_values('pert_id') == 
        limma_match_postpers_6hr_10um_realmatch.index.get_level_values('pert_id')),
    all(limma_sigs_6hr_10um.index.get_level_values('cell_id') == 
        limma_match_ctrls_6hr_10um_realmatch.index.get_level_values('cell_id')),
    all(limma_sigs_6hr_10um.index.get_level_values('cell_id') == 
        limma_match_postpers_6hr_10um_realmatch.index.get_level_values('cell_id')), 
    
    
    all(limma_sigs_24hr_10um.index.get_level_values('pert_id') == 
        limma_match_ctrls_24hr_10um_realmatch.index.get_level_values('pert_id')),
    all(limma_sigs_24hr_10um.index.get_level_values('pert_id') == 
        limma_match_postpers_24hr_10um_realmatch.index.get_level_values('pert_id')),
    all(limma_sigs_24hr_10um.index.get_level_values('cell_id') == 
        limma_match_ctrls_24hr_10um_realmatch.index.get_level_values('cell_id')),
    all(limma_sigs_24hr_10um.index.get_level_values('cell_id') == 
        limma_match_postpers_24hr_10um_realmatch.index.get_level_values('cell_id')),
    
    
    all(limma_sigs_24hr_5um.index.get_level_values('pert_id') == 
        limma_match_ctrls_24hr_5um_realmatch.index.get_level_values('pert_id')),
    all(limma_sigs_24hr_5um.index.get_level_values('pert_id') == 
        limma_match_postpers_24hr_5um_realmatch.index.get_level_values('pert_id')),
     all(limma_sigs_24hr_5um.index.get_level_values('cell_id') == 
        limma_match_ctrls_24hr_5um_realmatch.index.get_level_values('cell_id')),
    all(limma_sigs_24hr_5um.index.get_level_values('cell_id') == 
        limma_match_postpers_24hr_5um_realmatch.index.get_level_values('cell_id'))
])
# Out:
# True

# %%
limma_match_ctrls_6hr_10um_realmatch.to_pickle('/home/sgf2/DBMI_server/repo/ccdata/l1000_limma_w_controls/limma_6hr_10um_ctrls.pkl')
limma_match_postpers_6hr_10um_realmatch.to_pickle('/home/sgf2/DBMI_server/repo/ccdata/l1000_limma_w_controls/limma_6hr_10um_postpert.pkl')
limma_sigs_6hr_10um.to_pickle('/home/sgf2/DBMI_server/repo/ccdata/l1000_limma_w_controls/limma_6hr_10um_sigs.pkl')

limma_match_ctrls_24hr_10um_realmatch.to_pickle('/home/sgf2/DBMI_server/repo/ccdata/l1000_limma_w_controls/limma_24hr_10um_ctrls.pkl')
limma_match_postpers_24hr_10um_realmatch.to_pickle('/home/sgf2/DBMI_server/repo/ccdata/l1000_limma_w_controls/limma_24hr_10um_postpert.pkl')
limma_sigs_24hr_10um.to_pickle('/home/sgf2/DBMI_server/repo/ccdata/l1000_limma_w_controls/limma_24hr_10um_sigs.pkl')

limma_match_ctrls_24hr_5um_realmatch.to_pickle('/home/sgf2/DBMI_server/repo/ccdata/l1000_limma_w_controls/limma_24hr_5um_ctrls.pkl')
limma_match_postpers_24hr_5um_realmatch.to_pickle('/home/sgf2/DBMI_server/repo/ccdata/l1000_limma_w_controls/limma_24hr_5um_postpert.pkl')
limma_sigs_24hr_5um.to_pickle('/home/sgf2/DBMI_server/repo/ccdata/l1000_limma_w_controls/limma_24hr_5um_sigs.pkl')

# %%
limma_match_ctrls_6hr_10um_realmatch.to_csv('/home/sgf2/DBMI_server/repo/ccdata/l1000_limma_w_controls/limma_6hr_10um_ctrls.csv')
limma_match_postpers_6hr_10um_realmatch.to_csv('/home/sgf2/DBMI_server/repo/ccdata/l1000_limma_w_controls/limma_6hr_10um_postpert.csv')
limma_sigs_6hr_10um.to_csv('/home/sgf2/DBMI_server/repo/ccdata/l1000_limma_w_controls/limma_6hr_10um_sigs.csv')

limma_match_ctrls_24hr_10um_realmatch.to_csv('/home/sgf2/DBMI_server/repo/ccdata/l1000_limma_w_controls/limma_24hr_10um_ctrls.csv')
limma_match_postpers_24hr_10um_realmatch.to_csv('/home/sgf2/DBMI_server/repo/ccdata/l1000_limma_w_controls/limma_24hr_10um_postpert.csv')
limma_sigs_24hr_10um.to_csv('/home/sgf2/DBMI_server/repo/ccdata/l1000_limma_w_controls/limma_24hr_10um_sigs.csv')

limma_match_ctrls_24hr_5um_realmatch.to_csv('/home/sgf2/DBMI_server/repo/ccdata/l1000_limma_w_controls/limma_24hr_5um_ctrls.csv')
limma_match_postpers_24hr_5um_realmatch.to_csv('/home/sgf2/DBMI_server/repo/ccdata/l1000_limma_w_controls/limma_24hr_5um_postpert.csv')
limma_sigs_24hr_5um.to_csv('/home/sgf2/DBMI_server/repo/ccdata/l1000_limma_w_controls/limma_24hr_5um_sigs.csv')
